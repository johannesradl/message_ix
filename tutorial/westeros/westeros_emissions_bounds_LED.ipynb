# %% [markdown]
# # Westeros Tutorial Part II - Introducing emissions
# In the first part, the model chose not base the power system on wind power as electricity from  wind turbines was more expensive than electricity produced from coal. However, now we introduce emissions to investigate the impact of climate policy. Let's see what happens then.

# %%
import pandas as pd
import ixmp as ix
import message_ix

from message_ix.utils import make_df
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mp = ix.Platform(dbtype='HSQLDB')
# Out:
# INFO:root:launching ixmp.Platform with local HSQLDB database at 'C:\Users\jradl\.local\ixmp\localdb\default'
# ---------------------------------------------------------------------------
# org.flywaydb.core.internal.dbsupport.FlywaySqlExceptionPyRaisableTraceback (most recent call last)
# <ipython-input-2-00e57e8c119a> in <module>
# ----> 1 mp = ix.Platform(dbtype='HSQLDB')
#
# ~\Anaconda3\lib\site-packages\ixmp\core.py in __init__(self, dbprops, dbtype, jvmargs)
#      85                 logger().info("launching ixmp.Platform with local {} database at '{}'"
#      86                               .format(dbtype, dbprops))
# ---> 87                 self._jobj = java.ixmp.Platform("Python", dbprops, dbtype)
#      88             else:
#      89                 raise ValueError('Unknown dbtype: {}'.format(dbtype))
#
# ~\Anaconda3\lib\site-packages\jpype\_jclass.py in _javaInit(self, *args)
#     109     else:
#     110         self.__javaobject__ = self.__class__.__javaclass__.newClassInstance(
# --> 111             *args)
#     112
#     113
#
# org.flywaydb.core.internal.dbsupport.FlywaySqlExceptionPyRaisable: org.flywaydb.core.internal.dbsupport.FlywaySqlException:
# Unable to obtain Jdbc connection from DataSource (jdbc:hsqldb:file:C:\Users\jradl\.local\ixmp\localdb\default) for user 'ixmp': Database lock acquisition failure: lockFile: org.hsqldb.persist.LockFile@423b1ca4[file =C:\Users\jradl\.local\ixmp\localdb\default.lck, exists=true, locked=false, valid=false, ] method: checkHeartbeat read: 2019-05-28 09:33:12 heartbeat - read: -5679 ms.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# SQL State  : S1000
# Error Code : -451
# Message    : Database lock acquisition failure: lockFile: org.hsqldb.persist.LockFile@423b1ca4[file =C:\Users\jradl\.local\ixmp\localdb\default.lck, exists=true, locked=false, valid=false, ] method: checkHeartbeat read: 2019-05-28 09:33:12 heartbeat - read: -5679 ms.

# %%
model = 'Westeros Electrified'

base = message_ix.Scenario(mp, model=model, scenario='baseline')
scen = base.clone(model, 'emission_bound','introducing an upper bound on emissions', keep_sol=False)
scen.check_out()

# %%
year_df = scen.vintage_and_active_years()
vintage_years, act_years = year_df['year_vtg'], year_df['year_act']
model_horizon = scen.set('year')
country = 'Westeros'

# %% [markdown]
# ## Introducing Emissions

# %%
# first we introduce the emission specis CO2 and the emission category GHG
scen.add_set('emission', 'CO2')
scen.add_cat('emission', 'GHG', 'CO2')

# we now add CO2 emissions to the coal powerplant
base_emission_factor = {
    'node_loc': country,
    'year_vtg': vintage_years,
    'year_act': act_years,
    'mode': 'standard',
    'unit': 'USD/GWa',
}

emission_factor = make_df(base_emission_factor, technology= 'coal_ppl', emission= 'CO2', value = 100.)
scen.add_par('emission_factor', emission_factor)

# %% [markdown]
# ## Introduce a Bound on Emissions
#
# The `type_year: cumulative` assigns an upper bound on the *average emissions per year* over the entire time horizon.

# %%
scen.add_par('bound_emission', key=[country, 'GHG', 'all', 'cumulative'],
             val=2545., unit='tCO2') #

# %% [markdown]
# ## Time to Solve the Model

# %%
scen.commit(comment='introducing emissions and setting an upper bound')
scen.set_as_default()

# %%
scen.solve()

# %%
scen.var('OBJ')['lvl']

# %% [markdown]
# # Plotting Results

# %%
from tools import Plots
p = Plots(scen, country, firstyear=700)

# %% [markdown]
# # Activity
#
# How much energy is generated in each time period from the different potential sources?

# %%
p.plot_activity(baseyear=True, subset=['coal_ppl', 'wind_ppl'])

# %% [markdown]
# ## Capacity
#
# Given how many new plants are built, how many are actually used?

# %%
p.plot_capacity(baseyear=True, subset=['coal_ppl', 'wind_ppl'])

# %% [markdown]
# ## Electricity Price
#
# And how much does the electricity cost? These prices are taken from the **dual variables** of the solution and are given the name **shadow prices**. They reflect the marginal price of electricity, taken from the most expensive producer.
#
# Note that the price drop when the most expensive technology is no longer in the system.

# %%
p.plot_prices(subset=['light'], baseyear=True)

# %%
p.plot_capacity(baseyear=True, subset=['bulb', 'LED'])

# %% [markdown]
# # Fin
#
# With that, you have built and run your very first MESSAGEix model. Welcome to the community!
#
# Check us out on Github: https://github.com/iiasa/message_ix
#
# Get in touch with us online: https://groups.google.com/forum/message-ix
#
# And feel free to contact me with any further questions: gidden@iiasa.ac.at

# %%
mp.close_db()
